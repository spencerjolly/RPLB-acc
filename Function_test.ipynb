# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import xarray as xr
import h5py
from tqdm import tqdm
import time
from RPLB_acc_NoSTC import RPLB_acc_NoSTC
from RPLB_acc_NoSTC_2D import RPLB_acc_NoSTC_2D
from RPLB_acc_LC import RPLB_acc_LC
from RPLB_acc_LC_2D import RPLB_acc_LC_2D
from RPLB_acc_SC_2D import RPLB_acc_SC_2D
from RPLB_acc_g0 import RPLB_acc_g0
from RPLB_acc_g0_2D import RPLB_acc_g0_2D

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_0 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 0.6
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
z_0 = 0.005*(np.pi*w_0**2)/(lambda_0)  # collision position
beta_0 = 0.0

start = time.time()
KE_final = RPLB_acc_NoSTC(lambda_0, tau_0, w_0, P, Psi_0, phi_2, z_0, beta_0)
end = time.time()

print(end-start)
print(KE_final)
# Out:
# 0.018622159957885742
# 5710659.504500193

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_0 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 0.6
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
z_0 = 0.005*(np.pi*w_0**2)/(lambda_0)  # collision position
r_0 = 0.5*w_0
beta_0 = 0.0

start = time.time()
t, z, r, v_z, v_r, KE_final = RPLB_acc_NoSTC_2D(lambda_0, tau_0, w_0, P, Psi_0, phi_2, z_0, r_0, beta_0)
end = time.time()

print(end-start)
plt.plot(z, r)
print(KE_final)
# Out:
# 2.960082769393921
# 7095371.4742934955

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_0 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 5.4
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
phi_3 = 0*(1e-15)**3  # TOD s^3
z_0 = 0.042*(np.pi*w_0**2)/(lambda_0)  # collision position
beta_0 = 0.0
tau_p = -1.4*(1e-15)  # radial group delay s

start = time.time()
KE_final = RPLB_acc_LC(lambda_0, tau_0, w_0, P, Psi_0, phi_2, phi_3, z_0, beta_0, tau_p)
end = time.time()

print(end-start)
print(KE_final)
# Out:
# 8.795028924942017
# 9824383.030043425

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_0 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 5.4
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
phi_3 = 0*(1e-15)**3  # TOD s^3
z_0 = 0.042*(np.pi*w_0**2)/(lambda_0)  # collision position
r_0 = 0.5*w_0
beta_0 = 0.0
tau_p = -1.4*(1e-15)  # radial group delay s

start = time.time()
t, z, r, v_z, v_r, KE_final = RPLB_acc_LC_2D(lambda_0, tau_0, w_0, P, Psi_0, phi_2, phi_3, z_0, r_0, beta_0, tau_p)
end = time.time()

print(end-start)
plt.plot(z, r)
print(KE_final)
# Out:
# 109.59702849388123
# 2855294.1347483597

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_0 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 0.6
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
phi_3 = 0*(1e-15)**3  # TOD s^3
z_0 = 0.005*(np.pi*w_0**2)/(lambda_0)  # collision position
x_0 = 0.0*w_0
beta_0 = 0.0
tau_t = 10*(1e-15)

start = time.time()
t, z, x, v_z, v_x, KE_final = RPLB_acc_SC_2D(lambda_0, tau_0, w_0, P, Psi_0, phi_2, phi_3, z_0, x_0, beta_0, tau_t)
end = time.time()

print(end-start)
plt.plot(z, x)
print(KE_final)
# Out:
# 98.47325539588928
# 3047697.561076529

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_00 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 0.6
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
phi_3 = 0*(1e-15)**3  # TOD s^3
z_0 = 0.005*(np.pi*w_0**2)/(lambda_0)  # collision position
beta_0 = 0.0
g_0 = 0

start = time.time()
KE_final = RPLB_acc_g0(lambda_0, tau_0, w_00, P, Psi_0, phi_2, phi_3, z_0, beta_0, g_0)
end = time.time()

print(end-start)
print(KE_final)
# Out:
# 8.306166410446167
# 5712296.108074107

# %%
lambda_0 = 800e-9  # central wavelength
tau_0 = 10e-15  # FL pulse duration 1/e2 intensity half-width (same def as beam waist)
w_00 = 4e-6  # set beam waist
P = 100e12  # FL power
Psi_0 = 0.6
phi_2 = 0*(1e-15)**2  # Group Delay Dispersion s^2
phi_3 = 0*(1e-15)**3  # TOD s^3
z_0 = 0.005*(np.pi*w_0**2)/(lambda_0)  # collision position
r_0 = 0.0*w_0
beta_0 = 0.0
g_0 = 0

start = time.time()
t, z, r, v_z, v_r, KE_final = RPLB_acc_g0_2D(lambda_0, tau_0, w_00, P, Psi_0, phi_2, phi_3, z_0, r_0, beta_0, g_0)
end = time.time()

print(end-start)
plt.plot(z, r)
print(KE_final)
# Out:
# 106.14581084251404
# 5749074.936315945
